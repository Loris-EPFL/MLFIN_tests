# %% [markdown]
# # **Homework 2 (HW2)**
#
# ## **Deadline:** Wednesday, the 19th, 11:59pm
#
# ### **General recommendations:** There are still no credible ways to check for AI-generated solutions, therefore you are free to use LLM based chatbots. Nevertheless, for many questions you are expected to take decisions on some steps of the analysis the way humans do. Also, I have already tried to let ChatGPT solve this homework and what I got was not wrong, but rarely was the right solutions I am expecting from you. I ask you not to use any rolling window out-of-the-box functions for a specific reason i.e., you don't often know what it is under the hood of those. That is very dangerous, you should always be in full control.
#
# The goals of this homework is to let you play :) with:
# 1. Preprocessing of large financial datasets
# 2. Training and testing out-of-the-box models
# 3. Comparing the results of the out-of-the-box models with your own functions
# 4. Carrying out a meaningful analysis of your results

# %% [markdown]
# ## **1. Data Wrangling**
#
# ### **0. Preliminaries**
#
# - Fix random seed for reproducibility and import the needed libraries.
#
# **Context:** We want to begin analysing the stock market! How to start? We should get our hands on a financial dataset, with information on stock characteristics. Please go [here](https://jkpfactors.com/stock-char) and download the stocks characteristics for the US for the last forty years. Remember: stock characteristics, not factors...
#
# - Visualize the first rows to get an idea of what kind of variables are.
#
# - Column names are quite mysterious. Merge them with the information at ([this website](https://github.com/bkelly-lab/ReplicationCrisis/tree/master)).

# %% [markdown]
# ### **1. Data Cleaning & Transformation**
#
# - Are there any missing values? If so, which five columns have the most missing data?
#
# - Are all variables numerical? If not, which non-numeric variables need transformation?
#
# - Are there duplicate rows or duplicate stock entries for the same time period?
#
# - Convert all categorical variables, if any, into numerical representations.

# %% [markdown]
# ### **2. Descriptive Statistics & Distributions**
#
# - What are the five variables with the highest variance?
#
# - What are the five most skewed financial variables?
#
# - Which five financial variables have the most extreme outliers (justify your reasoning)?
#
# - Compute the kurtosis for all financial variables and list the five closest to a normal distribution.

# %% [markdown]
# ### **3. Correlation & Multicollinearity**
#
# - Compute pairwise correlations and identify the five most highly correlated variable pairs.
#
# - Calculate variance inflation factors (VIFs) and list the five variables most affected by multicollinearity.

# %% [markdown]
# ### **4. Time-Series Analysis**
#
# - Which five financial variables exhibit the highest autocorrelation in the pooled dataset?
#
# - Identify the five stocks with the most stable financial variables over the past 20 years. (Justify your assumptions)
#
# - Detect any structural breaks: Do certain financial variables exhibit significant shifts over time? (Justify your reasoning)
#
# - Compute rolling mean and rolling standard deviation for financial variables to check for trends. (Don't use the predefined rolling etc. functions. Be in total control of the rolling yourself!)

# %% [markdown]
# ### **5. Stock Performance**
#
# - Compute cumulative returns for each stock and identify the top and bottom performers over the past 10 and 20 years.
#
# - Identify the five stocks with the most extreme positive and negative monthly returns in the last 10 years.
#
# - Compute downside beta for each stock and list the five stocks most vulnerable to market downturns. (You don't need to run any regression)
#
# - Identify the five stocks that recover the fastest after a major drawdown.

# %% [markdown]
# ### **6. Ranking & Extremes**
#
# - Identify the five companies with the highest/lowest earnings variability.
#
# - Identify the five most extreme stock return events.
#
# - Find the five companies with the most extreme quarterly earnings surprises.
#
# - Identify the five financial variables with the highest standard deviation.
#
# - Rank companies based on financial persistence: Which five companies have the most consistent financial performance over time?
#
# - Find the five companies whose financial variables are closest to the median in terms of volatility.

# %% [markdown]
# ### **7. Grouping & Aggregation**
#
# - Which industry has the highest average return variance?
#
# - Which five industries show the highest cross-sectional dispersion in financial variables?
#
# - Compute monthly averages for financial variables and detect seasonal patterns.

# %% [markdown]
# ## **2. Linear regressions**
#
# ### **1. Sanity checks**
#
# - Now that we've played with stock characteristics, it is time to move to other tasks! Import the dataset (take care, not anything that is simple, it is necessarily easy :) )! **DONE**
#
# - Column names are again mysterious: be a modern Sherlock Holmes and refer to your previous knowledge to solve the case. **DONE, check mappings.csv**
#
# - Are there any duplicate entries for stocks in the same time period ? **Yes there are 4 of them**
#
#
# - Do all numerical columns contain valid values (e.g., no strings or special characters)?  **No, the return column is full of strings**
#
# - Are there any constant columns that provide no useful information? **Yes all of the unnamed 126, 127, 128, 129**
#
# - Are date formats consistent across the dataset?  **Yes aside from the NaNs they all follow the format month-day-year**
# - Are there extreme values that could affect regression results (e.g., highly skewed distributions)?  **Yes, for instance the column ami_126d has a skewedness > 2**

# %% [markdown]
# ### **1. The first (?) regression**
#
# - Milestone finance research showed that Book-to-Market is useful to predict returns. Let's dig up a bit - show a scatter plot of Book-to-Market and returns. **DONE**
#
# - Quite noisy, no? Let's try to run a linear regression! Is the coefficient significant? **Done with sklearn, very weak coefficient ~10e-3**
#
# - How do we know that `sklean` does not fool us? Let's check these results with matrix calculus and the direct OLS formulas. **DONE, we do find same intercept and slope so it seems sklearn did not fool us !**
#
# - Can we make money with this strategy? (if you say yes, why you taking the class run run make those money!) Why not? **No, there is to weak a correlation between market returns and Book-To-Market**
#
# - Try to run a simple market timing strategy with your model on a portfolio of five stocks. Do you manage to beat the market? **DONE, no we were far from beating market**

# %% [markdown]
# ### **2. Testing the results**
#
# - Make the return predictions with `sklearn`. **Done in the fit in the scatterplot**
#
# - Compare them with the actual formula (it might involve a bit of matrix calculus..) **Pretty similar, with R^2 diff of 0 and <10e-3 coeff/intercept difference**
#
# - Test now the accuracy of your model in an appropriate way. **Done via a Breusch-Pagan test**
#
# - Visualize in an efficient way the two distributions of the target variable. **We see that both the training distribution and the testing distribution are similar, this makes sense as we randomly sampled from the same dataset**
#
# - How do the resisuals behave? What can we imply? **DONE**

# %% [markdown]
# ## **3. Ridge regressions**
#
# ### **1. Basics**
#
# Once we understand linear regressions are just ridge regressions with null ridge penalty, we can leave this ''null penalty'' space safely and use this penalty :)
#
# - Now can control better the overfit, let's use the entire data to forecast returns with a ridge regression. What's the accuracy? Let's use MSE for now. **DONE, we have a good accuracy as the MSE is extremely low (~10e-7), but this is also due to the weights being close to 0 (10e-4)**
#
# - We suspect that `sklean` fool us? Let's check these results with matrix calculus and the direct ridge formulas. **DONE, we get similar distribution of the ridge coefficients which enables us to think sklearn did not fool us !**
#
# - What's the distribution of coefficients with a given regularization? How does it change when you vary it? **It is a gaussian centered in 0, changing the regularization flattens/widens the curve**
#
# - How does the accuracy change when you vary the shrinkage? **The accuracy stays constant until we hit alphas of magnitude 10e2 and then it drops up to a X3 factor at which point it stabilizes again**
#
# - We have been using MSE so far. It is well known it has some issues. Which ones? **Extremely sensitive to outliers**
#
# - Are there any changes when you standardize the predictors? **The distribution stays the same but the frequency scales up, this was expectable given the effect of standardizing a gaussian**
#
# - Let's move to R2 as a metric to test our work. Repeat the analysis above, when appropriate, with this new metric. **It's the inverse curve of our MSE one but it follows the same exponential pattern although now it's increasing instead of decreasing**
#
# - Is the matrix inversion trick really faster than the usual formula? Measure it! **It depends, if D>>N then inversion trick is much faster, and if N >> D then standard much faster**

# %% [markdown]
# ### **2. Portfolio construction**
#
# (you can consider the last 25 years of data only)
#
# - Build an equally weighted strategy using your predictions as portfolio weights. **DONE, init equal weight**
#
# - How does a change in the shrinkage impact the portfolio returns? **For no shrinkage, we are simply running a linear regression which means it's overfitting a bit but still giving a good signal, then as alpha increases, regularization shrinks the coefficients towards 0, thus collpasing the predictions towards 0 since they're a simple product of coefficients*inputs**
#
# - Try to vary the number of predictors you use in the ridge model. What happens to the test metrics? **We see that for 10-30% we probably aren't even including the predictive features anymore, which translates to extremely low mean returns, and that for 100% we seem to overfit a little at the start**
#
# - Does ridge regression perform differently for low-volatility vs. high-volatility stocks? **Ridge performs better on low-volatility stocks.
# It preserves signal and avoids overfitting.
# High-vol stocks likely have too much noise in returns for linear models like ridge to extract stable alpha.**

# %% [markdown]
# ### **3. Cross-validation**
#
# - Try to tune the shrinkage in different (non overlapping) rolling windows. Does it vary? (Don't use the predefined rolling etc. functions. Be in total control of the rolling yourself!) **It does not vary !**
#
# - Does it vary when the rolling windows are overlapping? **It doesn't vary either !**
#
# - Implement a nested cross-validation pipeline to carefully tune the hyperparameters and estimate the generalization performance.

# %% [markdown]
# ## **4. Lasso regressions**
#
# ### **1. Basics**
#
# Unlike ridge regressions, Lasso does not only shrink coefficients but effectively selects variables by setting coefficients for irrelevant variables to zero.
#
# - What's the distribution of coefficients with a given regularization? How does it change when you vary it?
#
# **As alpha grows, more and more coefficients are set to zero. This is characteristic of Lasso regressions, where only important features are kept, leaving out the rest as 0.**
#
# - How does the accuracy change when you vary the regularization?
#
# **As alpha grows, the accuracy decreases. This is because we are leaving out more and more features, which are important for the prediction.**
#
# - Are there any changes when you standardize the predictors?
#
# **Yes, with standardization, All features are penalized equally, feature selection is based on predictive power
# and Without standardization, Features with larger scales are penalized more heavily, potentially eliminating important predictors simply due to their scale**
#
# - Let's move to R2 as a metric to test our work. Repeat the analysis above, when appropriate, with this new metric.
#
# **R2 moves opposite to MSE, because R² decreases as alpha increases (opposite pattern to MSE). The Optimal alpha from R² perspective is typically lower than from MSE perspective**
#
# - Find the predictors that the model has set to zero. Do they vary much when you vary regularization?
#
# **The predictors that the model sets to zero vary significantly with regularization. As alpha increases, more predictors are set to zero.**
#
# - Do the predictors that the model decides to set to zero vary by industry?
#
# **Yes, the model decides to set highly volatile predictors to zero, and seems to focus on lower volatility predictors.**

# %% [markdown]
# ### **2. Portfolio construction**
#
# (you can consider the last 25 years of data only)
#
# - Buil an equally weighted strategy using your predictions as portfolio weights.
#
# - How does a change in the regularization impact the portfolio returns?
#
# ** **
#
# - Try to vary the number of predictors you use in the lasso model. What happens to the test metrics?
#
# - Does lasso regression perform differently for low-volatility vs. high-volatility stocks?

# %% [markdown]
# ### **3. Cross-validation**
#
# - Try to tune the regularization in different (non overlapping) rolling windows. Does it vary? (Don't use the predefined rolling etc. functions. Be in total control of the rolling yourself!)
#
# - Does it vary when the rolling windows are overlapping?
#
# - Implement a nested cross-validation pipeline to carefully tune the hyperparameters and estimate the generalization performance.

# %% [markdown]
# ## **5. Option Pricing**
#
# ### 1. **Simulating Black-Scholes Model**
#
# The **Black-Scholes model** (Black & Scholes, 1973) is a fundamental formula for pricing **European options**, assuming frictionless markets, no arbitrage, and constant volatility.
#
# - Write a function able to simulate option prices for call options for a grid of different combinations of inputs (Do not forget to set the random seed and to add the idiosyncratic value...)
#
# ## **Black-Scholes Model Parameters**
#
# | Parameter | Symbol | Range | Step Size |
# |-----------|--------|--------|-----------|
# | Stock Price | **S** | 40 to 69 | 1 |
# | Strike Price | **K** | 25 to 90 | 1 |
# | Risk-Free Rate | **r** | 0.00 to 0.05 | 0.01 |
# | Time to Expiration | **T** | 0.2 to 2.0 | 0.1 |
# | Volatility | **σ** | 0.23 to 0.75 | 0.1 |
#
# - Split the data into training and test samples.
#
# - Scale the input to the model. (Careful :) )

# %% [markdown]
# ### 2. **Learning Black-Scholes Model**
#
# - Start with a linear regression. What's its performance?
#
# **Performance is alright with a the following metrics :
#
#
# Performance by Moneyness Category:
# Deep OTM Options - Count: 54501, MSE: 10.044769, R²: 0.859749
# OTM Options - Count: 10418, MSE: 11.128603, R²: 0.709322
# ATM Options - Count: 6484, MSE: 11.831400, R²: 0.649157
# ITM Options - Count: 7684, MSE: 13.896705, R²: 0.537523
# Deep ITM Options - Count: 56439, MSE: 16.222311, R²: 0.562163
#
# **
#
# - Try to perform an analysis with a lasso model. Is it able to generalize? (Justify the use of the metric)
#
# **
# Yes, the lasso model is able to somewhat generalize. The performance is as follows, we have the following metrics :
#
# Best alpha: 0.0001
#
# Training Metrics:
# R-squared: 0.848413
# MSE: 16.712884
# MAE: 3.237397
#
# Testing Metrics:
# R-squared: 0.848616
# MSE: 16.691330
# MAE: 3.234931
#
# Feature Importance:
#               Feature  Coefficient  Abs_Coefficient
# 1        Strike Price    -7.525734         7.525734
# 0         Stock Price     4.946997         4.946997
# 4          Volatility     2.633008         2.633008
# 2  Time to Expiration     2.319096         2.319096
# 3      Risk-Free Rate     0.357968         0.357968
#
# Number of features used (non-zero coefficients): 5
#
# Performance on Noisier Data:
# MSE: 34.566110
# R-squared: 0.715151
#
# We can see both training and testing metrics are quite similar, which is a good sign and shows the model is able to generalize well.
#
# This result is expected as the best alpha is very close to 0, meaning that the ridge model is very similar to the linear regression model since all features are important, and minimal to none regularization is applied.
#
# **
#
# - Fit a ridge. How does it behave? (Justify the use of the metric)
#
# **
# From our metrics, Ridge performs identical to the lasso model, with the following metrics :
#
# Best alpha: 0.0001
#
# Ridge Regression Results:
# Coefficients: [ 4.94709697 -7.52583367  2.31919604  0.35806787  2.63310786]
# Intercept: 13.069378
#
# Training Metrics:
# R-squared: 0.848413
# MSE: 16.712884
# MAE: 3.237389
#
# Testing Metrics:
# R-squared: 0.848616
# MSE: 16.691329
# MAE: 3.234924
#
# Feature Importance:
#               Feature  Coefficient  Abs_Coefficient
# 1        Strike Price    -7.525834         7.525834
# 0         Stock Price     4.947097         4.947097
# 4          Volatility     2.633108         2.633108
# 2  Time to Expiration     2.319196         2.319196
# 3      Risk-Free Rate     0.358068         0.358068
#
# Performance on Noisier Data:
# MSE: 34.566247
# R-squared: 0.715150
#
# This result is expected as the best alpha is very close to 0, meaning that the ridge model is very similar to the linear regression model since all features are important, and minimal to none regularization is applied.
#
#
# **
#
# - Compare the perfomances of the three previous models in terms of moneyness of the option.
#
# ** All three models have similar performance in terms of moneyness of the option. WE can see the regularization in Lasso and Ridge has minimal impact with the chosen alpha values (very small, close to 0)
# The underlying relationship between features and option prices is well-captured by a linear model
# The problem doesn't benefit significantly from regularization.
# All models show declining performance as we move from Deep OTM to Deep ITM options
# This suggests that linear models struggle more with pricing options that have higher intrinsic value
#
# **
#
# - Compare the coefficients for the previous three models. Are there differences between them?
#
# **Not really, they are very similar. This suggests that the underlying relationship between features and option prices is well-captured by a linear model and regularization doesn't significantly change the coefficients in this case.**
#
# - How could you make these models behave better?
#
# **
# Since the Black-Scholes model is non-linear, we could try to incorporate non-linear features or use non-linear models like decision trees or neural networks.
# Here, since we are only allowed to use linear models, we will add non linear features to the linear regression model.
# **
#
# - Once you discover the trick, repeat the previous analysis (ie, fitting the three models and judging them)
#
# **Once fitted with non-linear features and scaled, the models perform much better. The performance is as follows :
#
# Linear Regression:
# R-squared: 0.9272
# MSE: 8.0260
#
# Ridge Regression:
# R-squared: 0.9272
# MSE: 8.0260
#
# Lasso Regression:
# R-squared: 0.9251
# MSE: 8.2596
#
# Which is significantly better than the previous models.
# **

# %% [markdown]
# ### 2. **Testing Black-Scholes Model**
#
# - How does the residuals in the linear regression behave? What does it imply?
#
#
# **
# The residuals look normally distributed with mean 0. This implies that the model is well specified.
# We also have independance of residuals from the Durbin-Watson test (p-value ≈ 2).
# However,the Breusch-Pagan test (p-value ≈ 0) implies Heteroscedasticity, which means prediction errors vary across different price ranges
# **
#
# - How are the parameters in the ridge regression varying when you vary regularization? And the accuracy?
#
# **
# The Ridge regression model demonstrates great stability across different regularization strengths. The modest shrinkage in coefficient magnitudes suggests that the model is not severely overfitting, even with weak regularization. The optimal regularization strength (α=113) provides a good balance, maintaining the interpretability of the model while likely improving its generalization performance.
# **
#
# - How are the parameters in the lasso regression varying when you vary regularization? And the accuracy?
#
#
# **The Lasso analysis reveals that:
#
# The option pricing model benefits from most features (15/16)
# Very weak regularization is optimal (α=0.001)
# The model shows high sensitivity to regularization strength
# Core option pricing components (Intrinsic, Strike, Time) are most robust
# This suggests using the weakly regularized model with 15 features, as it provides excellent predictive performance (R²=0.927) while still offering some feature selection benefit through the elimination of N_d2.**
#
# - Are they different from the parameters estimated by the linear regression?
#
# **
# The parameters in Ridge and Lasso regression differ from linear regression in ways that reflect their regularization approaches:
#
# Ridge: Maintains all features but with slightly shrunk coefficients, providing stability without drastically changing the model structure
# Lasso: Performs feature selection even at minimal regularization, with the potential for extreme sparsity at higher regularization levels
# In our case, the optimal Ridge model shows modest coefficient shrinkage compared to what linear regression would produce, while the optimal Lasso model eliminates one feature but otherwise produces coefficients very similar to linear regression due to the small optimal alpha value.
# **
#
# - You are back to your DGP. We are living unstable times, you decide to adapt to it and simulate more unstable option prices. How do ridge's and lasso's accuracies react?
#
# **
# When simulating more unstable option prices with higher volatility (from 2 to 5), both Ridge and Lasso regression models show a  decrease in predictive accuracy. The R² scores drop from approximately 0.86 to 0.73, representing about a 15% reduction in explained variance.
#
# The mean squared error more than doubles from ~15.2 to ~32.9, showing that while the models maintain reasonable relative accuracy, their absolute prediction errors grow substantially.
#
# Both models perform virtually identically in both normal and high volatility scenarios, suggesting that Lasso's feature selection property provides no advantage in this particular option pricing context.
#
#
# **
